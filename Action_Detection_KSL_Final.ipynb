# %% [markdown]
# # 1. Import and Install Dependencies

# %%
# !pip install opencv-python mediapipe scikit-learn matplotlib
# Out:
# Requirement already satisfied: opencv-python in c:\users\wjdgu\anaconda3\lib\site-packages (4.8.0.76)
# Requirement already satisfied: mediapipe in c:\users\wjdgu\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: scikit-learn in c:\users\wjdgu\anaconda3\lib\site-packages (1.2.1)
# Requirement already satisfied: matplotlib in c:\users\wjdgu\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\wjdgu\anaconda3\lib\site-packages (from opencv-python) (1.23.5)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\wjdgu\anaconda3\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: absl-py in c:\users\wjdgu\anaconda3\lib\site-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: opencv-contrib-python in c:\users\wjdgu\anaconda3\lib\site-packages (from mediapipe) (4.7.0.72)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\wjdgu\anaconda3\lib\site-packages (from mediapipe) (22.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\wjdgu\anaconda3\lib\site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\wjdgu\anaconda3\lib\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\wjdgu\anaconda3\lib\site-packages (from scikit-learn) (1.1.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\wjdgu\anaconda3\lib\site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\wjdgu\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\wjdgu\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\wjdgu\anaconda3\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\wjdgu\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\wjdgu\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\wjdgu\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\wjdgu\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\wjdgu\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\wjdgu\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: six>=1.5 in c:\users\wjdgu\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\wjdgu\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\wjdgu\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model): 
    #image = feed frame
    #model = Holistic model
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR -> RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB -> BGR
    return image, results

# %%
#connection_drawing_spec 커스텀 (optional)
def draw_styled_landmarks(image, results):
    #Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
#------------------------------------custom function 실행------------------------------------

# %%
def draw_custom_pose_landmarks(image, results):
    
    pose_landmark_subset = landmark_pb2.NormalizedLandmarkList(
      landmark = [
          #eye keypoints
          results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_EYE],#0 
          results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_EYE],#1
          #right arm keypoints
          results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_WRIST],#2
          results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ELBOW],#3
          results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_SHOULDER],#4 
          #left arm keypoints
          results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_WRIST],#5 
          results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ELBOW],#6
          results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_SHOULDER],#7
          #body keypoints
          results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_HIP],#8
          results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HIP]])#9
    
    #connection = [pose_landmark_subset index1, pose_landmark_subset index2]
    pose_landmark_subset_connections = [
        [2, 3], [3, 4], #right arm
        [5, 6], [6, 7], #left arm
        [4, 7], [4, 9], [8, 9], [7, 8]] #body

    #Draw pose connections
    mp_drawing.draw_landmarks(image, 
                             landmark_list = pose_landmark_subset, 
                             connections = pose_landmark_subset_connections,
                             landmark_drawing_spec = mp_drawing.DrawingSpec(color=(98,129,205), thickness=2, circle_radius=2), 
                             connection_drawing_spec = mp_drawing.DrawingSpec(color=(122,160,255), thickness=2, circle_radius=2)
                             )

# %%
def draw_custom_hand_landmarks(image, results):
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(149,140,205), thickness=2, circle_radius=2), 
                             mp_drawing.DrawingSpec(color=(185,174,255), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(205,182,141), thickness=2, circle_radius=2), 
                             mp_drawing.DrawingSpec(color=(255,226,176), thickness=2, circle_radius=2)
                             )

# %%
def draw_custom_face_landmarks(image, results):
    #face landmark subset
    face_landmark_subset = landmark_pb2.NormalizedLandmarkList(
          landmark = [
              #right eyebrow keypoints
              results.face_landmarks.landmark[46],#0 
              results.face_landmarks.landmark[53],#1
              results.face_landmarks.landmark[52],#2
              results.face_landmarks.landmark[65],#3
              results.face_landmarks.landmark[55],#4

              #left eyebrow keypoints
              results.face_landmarks.landmark[285],#5 
              results.face_landmarks.landmark[295],#6
              results.face_landmarks.landmark[282],#7
              results.face_landmarks.landmark[283],#8
              results.face_landmarks.landmark[276],#9

              #lip keypoints
              results.face_landmarks.landmark[61],#10 
              results.face_landmarks.landmark[81],#11
              results.face_landmarks.landmark[13],#12 
              results.face_landmarks.landmark[311],#13
              results.face_landmarks.landmark[291],#14
              results.face_landmarks.landmark[402],#15 
              results.face_landmarks.landmark[14],#16
              results.face_landmarks.landmark[178]])#17
    
    #connection = {face_landmark_subset index1, face_landmark_subset index2}
    face_landmark_subset_connections = [
        [0, 1], [1, 2], [2, 3], [3, 4], #right eybrow
        [5, 6], [6, 7], [7, 8], [8, 9], #left eyebrow
        [10, 11],[11, 12], [12, 13], [13, 14], [14, 15], [15, 16], [16, 17], [17, 10]] #lip
    
    mp_drawing.draw_landmarks(image, 
                             face_landmark_subset, 
                             face_landmark_subset_connections,
                             mp_drawing.DrawingSpec(color=(112,190,205), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(139,236,255), thickness=2, circle_radius=2)
                             )

# %% [markdown]
# # 3. Extract Keypoint Values
# results의 landmarks값 -> numpy array로 변환하기

# %%
poseIndex = np.array([22, 16, 14, 12, 24, 21, 15, 13, 11, 23])
faceIndex = np.array([61, 291, 81, 13, 311, 178, 14, 402, 285, 295, 282, 283, 276, 46, 53, 52, 65, 55])

def extract_keypoints_220(results):
    # result의 landmarks의 모든 key point values -> 하나의 numpy array 로 flatten
    #if landmarks has no value, fill numpy array with zero
    
    if results.pose_landmarks: #pose landmarks
        #pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten()
        i = 0
        pose = np.array([])
        for res in results.pose_landmarks.landmark:
            if i in poseIndex:
                pose = np.append(pose, np.array([res.x, res.y, res.z, res.visibility]))
            i = i + 1
    else:
        pose = np.zeros(132) #33*4

    if results.left_hand_landmarks: #left hand landmarks
        lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() 
    else:
        lh = np.zeros(63) #21*3

    if results.right_hand_landmarks: #right hand landmarks
        rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() 
    else:
        rh = np.zeros(63) #21*3
        
    #face landmarks
    if results.face_landmarks:
        #face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten()
        i = 0
        face = np.array([])
        for res in results.face_landmarks.landmark:
            if i in faceIndex:
                face = np.append(face, np.array([res.x, res.y, res.z]))
            i = i + 1
    else:
        face = np.zeros(54) #18*3
    
    
    #return np.concatenate([pose, lh, rh])
    return np.concatenate([pose, lh, rh, face])

# %%
def extract_keypoints_258(results):
    # result의 landmarks의 모든 key point values -> 하나의 numpy array 로 flatten
    #if landmarks has no value, fill numpy array with zero
    
    if results.pose_landmarks: #pose landmarks
        pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() 
    else:
        pose = np.zeros(132) #33*4

    if results.left_hand_landmarks: #left hand landmarks
        lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() 
    else:
        lh = np.zeros(63) #21*3

    if results.right_hand_landmarks: #right hand landmarks
        rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() 
    else:
        rh = np.zeros(63) #21*3
    
    
    #return np.concatenate([pose, lh, rh])
    return np.concatenate([pose, lh, rh])

# %%
def extract_keypoints_1662(results):
    # result의 landmarks의 모든 key point values -> 하나의 numpy array 로 flatten
    #if landmarks has no value, fill numpy array with zero
    
    if results.pose_landmarks: #pose landmarks
        pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() 
    else:
        pose = np.zeros(132) #33*4

    if results.left_hand_landmarks: #left hand landmarks
        lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() 
    else:
        lh = np.zeros(63) #21*3

    if results.right_hand_landmarks: #right hand landmarks
        rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() 
    else:
        rh = np.zeros(63) #21*3
    
    #face landmarks
    if results.face_landmarks:
        face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() 
    else:
        face = np.zeros(1404) #468*3
    
    #return np.concatenate([pose, lh, rh])
    return np.concatenate([pose, lh, rh, face])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
#pandas
# !pip install xlrd
# !pip install openpyxl
# !pip install pandas
import pandas as pd
# Out:
# ^C
# Requirement already satisfied: xlrd in c:\users\wjdgu\anaconda3\lib\site-packages (2.0.1)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# Requirement already satisfied: openpyxl in c:\users\wjdgu\anaconda3\lib\site-packages (3.0.10)
# Requirement already satisfied: et_xmlfile in c:\users\wjdgu\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# Requirement already satisfied: pandas in c:\users\wjdgu\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\wjdgu\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\wjdgu\anaconda3\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\wjdgu\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\wjdgu\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\wjdgu\anaconda3\lib\site-packages)

# %%
import pandas as pd

# %%
# 파일명
file_name = '45.xlsx'

# Daraframe형식으로 엑셀 파일 읽기
df = pd.read_excel(file_name, sheet_name='Sheet1')

list_res = df.loc[:,'단어'].to_list()
print(list_res)
# Out:
# ['가슴', '개', '귀', '내일', '누나', '다리', '동생', '뒤', '딸', '머리', '목', '물', '발', '배', '불', '뼈', '선생님', '손', '아기', '아내', '아들', '아빠', '앞', '어제', '엄마', '옆쪽', '오늘', '오른쪽', '왼쪽', '위', '친구', '코', '팔', '학교', 1, 2, 3, 4, 5, 6, 7, 8, 9, 0]

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('datas') 

#num of videos
no_sequences = 100

#actions = np.array(['가스', '가슴', '갇히다'])
actions = np.array(list_res)

# 1 Video = 50 frames
sequence_length = 30

# %%
len(actions)
# Out:
# 44

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
##extract keypoints from video
def frame_capture(action, sequence, video):
    cap = cv2.VideoCapture(video)
    
    # Set mediapipe model 
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        frame_num = 0
        while cap.isOpened():
            # Read feed
            ret, frame = cap.read()
            if ret == False:
                break
                
            # Make detections
            image, results = mediapipe_detection(frame, holistic)  
            # Draw landmarks
            #draw_styled_landmarks(image, results)
            draw_custom_pose_landmarks(image, results)
            draw_custom_hand_landmarks(image, results)
            draw_custom_face_landmarks(image, results)

            # Show to screen
            cv2.imshow('OpenCV Video', image)

            # export keypoints
            keypoints = extract_keypoints(results) #results of frame -> numpy array
            npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
            np.save(npy_path, keypoints) #save numpy array in directory
            
            #increase frame_num
            frame_num = frame_num + 1
                
            # Break gracefully
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
                
        cap.release()
        cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
def GetKeypoint(src):
    poseIndex = np.array([22, 16, 14, 12, 24, 21, 15, 13, 11, 23])
    faceIndex = np.array([61, 291, 81, 13, 311, 178, 14, 402, 285, 295, 282, 283, 276, 46, 53, 52, 65, 55])
    result = np.array([])
    #for p in poseIndex:
    #    for i in range(0,4):
    #        result = np.append(result, src[4*p + i])
    #        
    #result = np.append(result, src[133:133+126])
    result = np.append(result, src[0:258])
    
    for f in faceIndex:
        for i in range(0,3):
            result = np.append(result, src[258 + 3*f + i])
    
    return result

# %%
# ------------------------양손, 양손 + 포즈, 양손 + 포즈 + 얼굴 ------------------------

import fnmatch #폴더 안에 있는 npy 개수 계산하기 위함

#create two blank arrays
sequences, labels = [], [] 
#sequences(=videos) = feature data = x data 
#labels = label data = y data

for action in actions: 
    for sequence in range(no_sequences): #each action has 60 sequences(=videos)
        window = []
        
        #폴더 안에 있는 npy 개수(= frame 수) 계산
        file_count = len(fnmatch.filter(os.listdir(os.path.join(DATA_PATH, action, str(sequence))), '*.npy'))
        
        #저장된 npy 수가 원하는 sequence_length보다 같거나 많을 경우
        if(file_count >= sequence_length):  
            #앞에 있는 npy 버리고, start부터 끝까지 sequence_length개의 npy 가져오기
            start = (file_count - sequence_length)//2
            for frame_num in range(sequence_length):
                res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(start + frame_num)))
                #res_tmp = res[132:258]     # 양손만
                #res_tmp = GetKeypoint(res)  # 포즈 + 손 + 일부 얼굴
                res_tmp = res[0:258]    # 포즈 + 양손

                window.append(res_tmp)
        #저장된 npy 수가 원하는 sequence_length보다 적을 경우
        else:
            #앞에 0으로 채운 npy 추가하기
            for frame_num in range(sequence_length - file_count):
                res = np.zeros(258) #132 + 63 + 63
                window.append(res)
            for frame_num in range(file_count):
                res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
                window.append(res)
                              
        #map label
        sequences.append(window)
        labels.append(label_map[action])

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (4400, 30, 258)

# %%
y = to_categorical(labels).astype(int) 
#converted label from int to binary array
#1 -> [1,0,0], 2 -> [0,1,0], 3 -> [0,0,1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
#split x,y data into train data and test data
#train data 95%, test data size 5%

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)
#tensor board is used to monitor neural network training and it's accuracy

# %%
import tensorflow as tf
from tensorflow.keras.layers import Add, Input, Embedding, GlobalAveragePooling1D, Conv1D, ReLU, MaxPooling1D, LSTM, Dense, Bidirectional, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential, Model

#Residual Block 구현
def residual_block(x, filters, kernel_size=3, stride=1):
    # Shortcut Connection
    shortcut = x
    
    # Main Path
    x = Conv1D(filters, kernel_size=kernel_size, strides=stride, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    
    x = Conv1D(filters, kernel_size=kernel_size, strides=stride, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    
    x = Conv1D(filters, kernel_size=kernel_size, strides=stride, padding='same')(x)
    x = BatchNormalization()(x)
    
    # Shortcut Connection 추가
    x = Add()([x, shortcut])
    x = ReLU()(x)
    
    return x


input_layer = Input(shape=(30,258))

x = Conv1D(64, kernel_size=3, activation='relu')(input_layer)
x = BatchNormalization()(x)
x = ReLU()(x)
x = MaxPooling1D(pool_size=2)(x)

# --------------------------------------------------------
x = residual_block(x, filters=64)
x = MaxPooling1D(pool_size=2, padding='same')(x)

x = residual_block(x, filters=64)
x = MaxPooling1D(pool_size=2, padding='same')(x)

x = residual_block(x, filters=64)
x = MaxPooling1D(pool_size=2)(x)

# --------------------------------------------------------

x = Bidirectional(LSTM(64, return_sequences=True, activation='tanh'))(x)
x = Dropout(0.3)(x)
x = Bidirectional(LSTM(128, return_sequences=True, activation='tanh'))(x)
x = Dropout(0.3)(x)
x = Bidirectional(LSTM(64, return_sequences=True, activation='tanh'))(x)
x = Dropout(0.3)(x)
x = Bidirectional(LSTM(64, return_sequences=True, activation='tanh'))(x)
x = Dropout(0.3)(x)
x = LSTM(64, return_sequences=False, activation='relu')(x)


output_layer = Dense(actions.shape[0], activation='softmax')(x)
model = Model(inputs=input_layer, outputs=output_layer)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 30, 258)]    0           []
#
#  conv1d_30 (Conv1D)             (None, 28, 64)       49600       ['input_4[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 28, 64)      256         ['conv1d_30[0][0]']
#  ormalization)
#
#  re_lu_30 (ReLU)                (None, 28, 64)       0           ['batch_normalization_30[0][0]']
#
#  max_pooling1d_12 (MaxPooling1D  (None, 14, 64)      0           ['re_lu_30[0][0]']
#  )
#
#  conv1d_31 (Conv1D)             (None, 14, 64)       12352       ['max_pooling1d_12[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 14, 64)      256         ['conv1d_31[0][0]']
#  ormalization)
#
#  re_lu_31 (ReLU)                (None, 14, 64)       0           ['batch_normalization_31[0][0]']
#
#  conv1d_32 (Conv1D)             (None, 14, 64)       12352       ['re_lu_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 14, 64)      256         ['conv1d_32[0][0]']
#  ormalization)
#
#  re_lu_32 (ReLU)                (None, 14, 64)       0           ['batch_normalization_32[0][0]']
#
#  conv1d_33 (Conv1D)             (None, 14, 64)       12352       ['re_lu_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 14, 64)      256         ['conv1d_33[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 14, 64)       0           ['batch_normalization_33[0][0]',
#                                                                   'max_pooling1d_12[0][0]']
#
#  re_lu_33 (ReLU)                (None, 14, 64)       0           ['add_9[0][0]']
#
#  max_pooling1d_13 (MaxPooling1D  (None, 7, 64)       0           ['re_lu_33[0][0]']
#  )
#
#  conv1d_34 (Conv1D)             (None, 7, 64)        12352       ['max_pooling1d_13[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 7, 64)       256         ['conv1d_34[0][0]']
#  ormalization)
#
#  re_lu_34 (ReLU)                (None, 7, 64)        0           ['batch_normalization_34[0][0]']
#
#  conv1d_35 (Conv1D)             (None, 7, 64)        12352       ['re_lu_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 7, 64)       256         ['conv1d_35[0][0]']
#  ormalization)
#
#  re_lu_35 (ReLU)                (None, 7, 64)        0           ['batch_normalization_35[0][0]']
#
#  conv1d_36 (Conv1D)             (None, 7, 64)        12352       ['re_lu_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 7, 64)       256         ['conv1d_36[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 7, 64)        0           ['batch_normalization_36[0][0]',
#                                                                   'max_pooling1d_13[0][0]']
#
#  re_lu_36 (ReLU)                (None, 7, 64)        0           ['add_10[0][0]']
#
#  max_pooling1d_14 (MaxPooling1D  (None, 4, 64)       0           ['re_lu_36[0][0]']
#  )
#
#  conv1d_37 (Conv1D)             (None, 4, 64)        12352       ['max_pooling1d_14[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 4, 64)       256         ['conv1d_37[0][0]']
#  ormalization)
#
#  re_lu_37 (ReLU)                (None, 4, 64)        0           ['batch_normalization_37[0][0]']
#
#  conv1d_38 (Conv1D)             (None, 4, 64)        12352       ['re_lu_37[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 4, 64)       256         ['conv1d_38[0][0]']
#  ormalization)
#
#  re_lu_38 (ReLU)                (None, 4, 64)        0           ['batch_normalization_38[0][0]']
#  conv1d_39 (Conv1D)             (None, 4, 64)        12352       ['re_lu_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 4, 64)       256         ['conv1d_39[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 4, 64)        0           ['batch_normalization_39[0][0]',
#                                                                   'max_pooling1d_14[0][0]']
#
#  re_lu_39 (ReLU)                (None, 4, 64)        0           ['add_11[0][0]']
#
#  max_pooling1d_15 (MaxPooling1D  (None, 2, 64)       0           ['re_lu_39[0][0]']
#  )
#
#  bidirectional_12 (Bidirectiona  (None, 2, 128)      66048       ['max_pooling1d_15[0][0]']
#  l)
#
#  dropout_12 (Dropout)           (None, 2, 128)       0           ['bidirectional_12[0][0]']
#
#  bidirectional_13 (Bidirectiona  (None, 2, 256)      263168      ['dropout_12[0][0]']
#  l)
#
#  dropout_13 (Dropout)           (None, 2, 256)       0           ['bidirectional_13[0][0]']
#
#  bidirectional_14 (Bidirectiona  (None, 2, 128)      164352      ['dropout_13[0][0]']
#  l)
#
#  dropout_14 (Dropout)           (None, 2, 128)       0           ['bidirectional_14[0][0]']
#
#  bidirectional_15 (Bidirectiona  (None, 2, 128)      98816       ['dropout_14[0][0]']
#  l)
#
#  dropout_15 (Dropout)           (None, 2, 128)       0           ['bidirectional_15[0][0]']
#
#  lstm_19 (LSTM)                 (None, 64)           49408       ['dropout_15[0][0]']
#
#  dense_3 (Dense)                (None, 44)           2860        ['lstm_19[0][0]']
#
# ==================================================================================================
# Total params: 807,980
# Trainable params: 806,700
# Non-trainable params: 1,280
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=200, callbacks=[tb_callback])
# Out:
# Epoch 1/200
# 124/124 [==============================] - 15s 38ms/step - loss: 3.5292 - categorical_accuracy: 0.0366
# Epoch 2/200
# 124/124 [==============================] - 5s 37ms/step - loss: 3.2223 - categorical_accuracy: 0.0412
# Epoch 3/200
# 124/124 [==============================] - 5s 37ms/step - loss: 3.1687 - categorical_accuracy: 0.0631
# Epoch 4/200
# 124/124 [==============================] - 5s 37ms/step - loss: 3.1051 - categorical_accuracy: 0.0715
# Epoch 5/200
# 124/124 [==============================] - 5s 37ms/step - loss: 3.0523 - categorical_accuracy: 0.0843
# Epoch 6/200
# 124/124 [==============================] - 5s 37ms/step - loss: 2.9685 - categorical_accuracy: 0.1040
# Epoch 7/200
# 124/124 [==============================] - 5s 37ms/step - loss: 2.9008 - categorical_accuracy: 0.1136
# Epoch 8/200
# 124/124 [==============================] - 5s 37ms/step - loss: 2.6612 - categorical_accuracy: 0.1321
# Epoch 9/200
# 124/124 [==============================] - 5s 37ms/step - loss: 2.5049 - categorical_accuracy: 0.1657
# Epoch 10/200
# 124/124 [==============================] - 5s 37ms/step - loss: 2.3216 - categorical_accuracy: 0.1977
# Epoch 11/200
# 124/124 [==============================] - 5s 37ms/step - loss: 2.1804 - categorical_accuracy: 0.2354
# Epoch 12/200
# 124/124 [==============================] - 5s 37ms/step - loss: 2.0490 - categorical_accuracy: 0.2558
# Epoch 13/200
# 124/124 [==============================] - 5s 36ms/step - loss: 1.9088 - categorical_accuracy: 0.2874
# Epoch 14/200
# 124/124 [==============================] - 5s 36ms/step - loss: 1.9025 - categorical_accuracy: 0.3010
# Epoch 15/200
# 124/124 [==============================] - 5s 37ms/step - loss: 1.8118 - categorical_accuracy: 0.3172
# Epoch 16/200
# 124/124 [==============================] - 5s 37ms/step - loss: 1.6917 - categorical_accuracy: 0.3528
# Epoch 17/200
# 124/124 [==============================] - 5s 37ms/step - loss: 1.6431 - categorical_accuracy: 0.3811
# Epoch 18/200
# 124/124 [==============================] - 5s 37ms/step - loss: 1.5600 - categorical_accuracy: 0.4179
# Epoch 19/200
# 124/124 [==============================] - 5s 37ms/step - loss: 1.5947 - categorical_accuracy: 0.4126
# Epoch 20/200
# 124/124 [==============================] - 5s 37ms/step - loss: 1.4563 - categorical_accuracy: 0.4518
# Epoch 21/200
# 124/124 [==============================] - 5s 37ms/step - loss: 1.3966 - categorical_accuracy: 0.4692
# Epoch 22/200
# 124/124 [==============================] - 5s 37ms/step - loss: 1.3692 - categorical_accuracy: 0.4957
# Epoch 23/200
# 124/124 [==============================] - 5s 37ms/step - loss: 1.3507 - categorical_accuracy: 0.5023
# Epoch 24/200
# 124/124 [==============================] - 5s 37ms/step - loss: 1.2268 - categorical_accuracy: 0.5301
# Epoch 25/200
# 124/124 [==============================] - 5s 37ms/step - loss: 1.1953 - categorical_accuracy: 0.5404
# Epoch 26/200
# 124/124 [==============================] - 5s 37ms/step - loss: 1.1950 - categorical_accuracy: 0.5434
# Epoch 27/200
# 124/124 [==============================] - 5s 37ms/step - loss: 1.1240 - categorical_accuracy: 0.5725
# Epoch 28/200
# 124/124 [==============================] - 5s 37ms/step - loss: 1.0883 - categorical_accuracy: 0.5843
# Epoch 29/200
# 124/124 [==============================] - 5s 37ms/step - loss: 1.0915 - categorical_accuracy: 0.5806
# Epoch 30/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.9866 - categorical_accuracy: 0.6109
# Epoch 31/200
# 124/124 [==============================] - 5s 37ms/step - loss: 1.0479 - categorical_accuracy: 0.6038
# Epoch 32/200
# 124/124 [==============================] - 5s 37ms/step - loss: 1.0134 - categorical_accuracy: 0.6116
# Epoch 33/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.9976 - categorical_accuracy: 0.6154
# Epoch 34/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.8950 - categorical_accuracy: 0.6515
# Epoch 35/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.9140 - categorical_accuracy: 0.6341
# Epoch 36/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.8859 - categorical_accuracy: 0.6609
# Epoch 37/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.8348 - categorical_accuracy: 0.6631
# Epoch 38/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.8219 - categorical_accuracy: 0.6912
# Epoch 39/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.7622 - categorical_accuracy: 0.6970
# Epoch 40/200
# 124/124 [==============================] - 5s 36ms/step - loss: 0.7690 - categorical_accuracy: 0.6985
# Epoch 41/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.7845 - categorical_accuracy: 0.6914
# Epoch 42/200
# 124/124 [==============================] - 5s 36ms/step - loss: 0.7894 - categorical_accuracy: 0.6957
# Epoch 43/200
# 124/124 [==============================] - 5s 36ms/step - loss: 0.6868 - categorical_accuracy: 0.7285
# Epoch 44/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.7081 - categorical_accuracy: 0.7341
# Epoch 45/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.7320 - categorical_accuracy: 0.7232
# Epoch 46/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.6640 - categorical_accuracy: 0.7452
# Epoch 47/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.6427 - categorical_accuracy: 0.7545
# Epoch 48/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.5934 - categorical_accuracy: 0.7657
# Epoch 49/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.6003 - categorical_accuracy: 0.7687
# Epoch 50/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.6235 - categorical_accuracy: 0.7624
# Epoch 51/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.5594 - categorical_accuracy: 0.7816
# Epoch 52/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.5423 - categorical_accuracy: 0.7896
# Epoch 53/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.5213 - categorical_accuracy: 0.8045
# Epoch 54/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.5595 - categorical_accuracy: 0.7952
# Epoch 55/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.5390 - categorical_accuracy: 0.7947
# Epoch 56/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.5555 - categorical_accuracy: 0.7881
# Epoch 57/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.5348 - categorical_accuracy: 0.8000
# Epoch 58/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.5160 - categorical_accuracy: 0.8061
# Epoch 59/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.4595 - categorical_accuracy: 0.8316
# Epoch 60/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.4626 - categorical_accuracy: 0.8225
# Epoch 61/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.4435 - categorical_accuracy: 0.8258
# Epoch 62/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.4438 - categorical_accuracy: 0.8364
# Epoch 63/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.4602 - categorical_accuracy: 0.8301
# Epoch 64/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.4500 - categorical_accuracy: 0.8308
# Epoch 65/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.4915 - categorical_accuracy: 0.8283
# Epoch 66/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.4145 - categorical_accuracy: 0.8399
# Epoch 67/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.4133 - categorical_accuracy: 0.8465
# Epoch 68/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.4019 - categorical_accuracy: 0.8525
# Epoch 69/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.3522 - categorical_accuracy: 0.8626
# Epoch 70/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.3977 - categorical_accuracy: 0.8518
# Epoch 71/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.3822 - categorical_accuracy: 0.8631
# Epoch 72/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.3838 - categorical_accuracy: 0.8614
# Epoch 73/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.4185 - categorical_accuracy: 0.8510
# Epoch 74/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.3233 - categorical_accuracy: 0.8768
# Epoch 75/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.3221 - categorical_accuracy: 0.8813
# Epoch 76/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.3300 - categorical_accuracy: 0.8788
# Epoch 77/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.3259 - categorical_accuracy: 0.8745
# Epoch 78/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.3666 - categorical_accuracy: 0.8687
# Epoch 79/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.3470 - categorical_accuracy: 0.8737
# Epoch 80/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.3227 - categorical_accuracy: 0.8833
# Epoch 81/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.3350 - categorical_accuracy: 0.8788
# Epoch 82/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2685 - categorical_accuracy: 0.8980
# Epoch 83/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.3428 - categorical_accuracy: 0.8806
# Epoch 84/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2829 - categorical_accuracy: 0.8919
# Epoch 85/200
# 124/124 [==============================] - 5s 36ms/step - loss: 0.3015 - categorical_accuracy: 0.8879
# Epoch 86/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2663 - categorical_accuracy: 0.8955
# Epoch 87/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2853 - categorical_accuracy: 0.8982
# Epoch 88/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2810 - categorical_accuracy: 0.8992
# Epoch 89/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2750 - categorical_accuracy: 0.9020
# Epoch 90/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.3041 - categorical_accuracy: 0.8939
# Epoch 91/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2692 - categorical_accuracy: 0.9061
# Epoch 92/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2724 - categorical_accuracy: 0.9056
# Epoch 93/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2927 - categorical_accuracy: 0.8995
# Epoch 94/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2235 - categorical_accuracy: 0.9205
# Epoch 95/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2370 - categorical_accuracy: 0.9164
# Epoch 96/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2442 - categorical_accuracy: 0.9124
# Epoch 97/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2473 - categorical_accuracy: 0.9146
# Epoch 98/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2074 - categorical_accuracy: 0.9285
# Epoch 99/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2419 - categorical_accuracy: 0.9177
# Epoch 100/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2707 - categorical_accuracy: 0.9030
# Epoch 101/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2014 - categorical_accuracy: 0.9260
# Epoch 102/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2109 - categorical_accuracy: 0.9215
# Epoch 103/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2089 - categorical_accuracy: 0.9280
# Epoch 104/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2507 - categorical_accuracy: 0.9139
# Epoch 105/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1961 - categorical_accuracy: 0.9295
# Epoch 106/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2434 - categorical_accuracy: 0.9207
# Epoch 107/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2012 - categorical_accuracy: 0.9263
# Epoch 108/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1776 - categorical_accuracy: 0.9384
# Epoch 109/200
# 124/124 [==============================] - 5s 36ms/step - loss: 0.1972 - categorical_accuracy: 0.9298
# Epoch 110/200
# 124/124 [==============================] - 5s 36ms/step - loss: 0.1795 - categorical_accuracy: 0.9343
# Epoch 111/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2156 - categorical_accuracy: 0.9260
# Epoch 112/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2569 - categorical_accuracy: 0.9174
# Epoch 113/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2124 - categorical_accuracy: 0.9295
# Epoch 114/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1940 - categorical_accuracy: 0.9306
# Epoch 115/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2096 - categorical_accuracy: 0.9306
# Epoch 116/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1957 - categorical_accuracy: 0.9336
# Epoch 117/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1971 - categorical_accuracy: 0.9354
# Epoch 118/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1599 - categorical_accuracy: 0.9455
# Epoch 119/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1801 - categorical_accuracy: 0.9386
# Epoch 120/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.2279 - categorical_accuracy: 0.9253
# Epoch 121/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1710 - categorical_accuracy: 0.9414
# Epoch 122/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1657 - categorical_accuracy: 0.9429
# Epoch 123/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1783 - categorical_accuracy: 0.9427
# Epoch 124/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1400 - categorical_accuracy: 0.9525
# Epoch 125/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1288 - categorical_accuracy: 0.9543
# Epoch 126/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1916 - categorical_accuracy: 0.9364
# Epoch 127/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1515 - categorical_accuracy: 0.9510
# Epoch 128/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1543 - categorical_accuracy: 0.9500
# Epoch 129/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1485 - categorical_accuracy: 0.9495
# Epoch 130/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1857 - categorical_accuracy: 0.9374
# Epoch 131/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1669 - categorical_accuracy: 0.9437
# Epoch 132/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1174 - categorical_accuracy: 0.9556
# Epoch 133/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1616 - categorical_accuracy: 0.9444
# Epoch 134/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1361 - categorical_accuracy: 0.9573
# Epoch 135/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1557 - categorical_accuracy: 0.9515
# Epoch 136/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1427 - categorical_accuracy: 0.9533
# Epoch 137/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1145 - categorical_accuracy: 0.9616
# Epoch 138/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1322 - categorical_accuracy: 0.9563
# Epoch 139/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1379 - categorical_accuracy: 0.9558
# Epoch 140/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1715 - categorical_accuracy: 0.9475
# Epoch 141/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1328 - categorical_accuracy: 0.9558
# Epoch 142/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1383 - categorical_accuracy: 0.9583
# Epoch 143/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1538 - categorical_accuracy: 0.9508
# Epoch 144/200
# 124/124 [==============================] - 4s 36ms/step - loss: 0.1125 - categorical_accuracy: 0.9611
# Epoch 145/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1371 - categorical_accuracy: 0.9588
# Epoch 146/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1365 - categorical_accuracy: 0.9576
# Epoch 147/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1364 - categorical_accuracy: 0.9553
# Epoch 148/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1916 - categorical_accuracy: 0.9412
# Epoch 149/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1322 - categorical_accuracy: 0.9573
# Epoch 150/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1057 - categorical_accuracy: 0.9664
# Epoch 151/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1117 - categorical_accuracy: 0.9649
# Epoch 152/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1707 - categorical_accuracy: 0.9470
# Epoch 153/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0706 - categorical_accuracy: 0.9773
# Epoch 154/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1195 - categorical_accuracy: 0.9646
# Epoch 155/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1062 - categorical_accuracy: 0.9624
# Epoch 156/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1072 - categorical_accuracy: 0.9636
# Epoch 157/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1165 - categorical_accuracy: 0.9609
# Epoch 158/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1241 - categorical_accuracy: 0.9604
# Epoch 159/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1472 - categorical_accuracy: 0.9563
# Epoch 160/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0767 - categorical_accuracy: 0.9755
# Epoch 161/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1324 - categorical_accuracy: 0.9588
# Epoch 162/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1327 - categorical_accuracy: 0.9616
# Epoch 163/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1061 - categorical_accuracy: 0.9662
# Epoch 164/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0996 - categorical_accuracy: 0.9720
# Epoch 165/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0868 - categorical_accuracy: 0.9725
# Epoch 166/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1388 - categorical_accuracy: 0.9588
# Epoch 167/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0923 - categorical_accuracy: 0.9758
# Epoch 168/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0981 - categorical_accuracy: 0.9699
# Epoch 169/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0957 - categorical_accuracy: 0.9710
# Epoch 170/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0894 - categorical_accuracy: 0.9720
# Epoch 171/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0971 - categorical_accuracy: 0.9674
# Epoch 172/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1027 - categorical_accuracy: 0.9715
# Epoch 173/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1250 - categorical_accuracy: 0.9649
# Epoch 174/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0715 - categorical_accuracy: 0.9780
# Epoch 175/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0937 - categorical_accuracy: 0.9740
# Epoch 176/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0827 - categorical_accuracy: 0.9758
# Epoch 177/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0964 - categorical_accuracy: 0.9715
# Epoch 178/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0771 - categorical_accuracy: 0.9765
# Epoch 179/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1309 - categorical_accuracy: 0.9616
# Epoch 180/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0774 - categorical_accuracy: 0.9758
# Epoch 181/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1049 - categorical_accuracy: 0.9699
# Epoch 182/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0976 - categorical_accuracy: 0.9707
# Epoch 183/200
# 124/124 [==============================] - 5s 38ms/step - loss: 0.1093 - categorical_accuracy: 0.9682
# Epoch 184/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0881 - categorical_accuracy: 0.9717
# Epoch 185/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0736 - categorical_accuracy: 0.9778
# Epoch 186/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0961 - categorical_accuracy: 0.9715
# Epoch 187/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1406 - categorical_accuracy: 0.9619
# Epoch 188/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0580 - categorical_accuracy: 0.9826
# Epoch 189/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0709 - categorical_accuracy: 0.9785
# Epoch 190/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0848 - categorical_accuracy: 0.9763
# Epoch 191/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1261 - categorical_accuracy: 0.9578
# Epoch 192/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1210 - categorical_accuracy: 0.9646
# Epoch 193/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0976 - categorical_accuracy: 0.9715
# Epoch 194/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0707 - categorical_accuracy: 0.9793
# Epoch 195/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0775 - categorical_accuracy: 0.9750
# Epoch 196/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0836 - categorical_accuracy: 0.9765
# Epoch 197/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.1075 - categorical_accuracy: 0.9684
# Epoch 198/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0918 - categorical_accuracy: 0.9747
# Epoch 199/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0585 - categorical_accuracy: 0.9795
# Epoch 200/200
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0779 - categorical_accuracy: 0.9722

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 88, 64)            24256
#
#  batch_normalization_2 (Batc  (None, 88, 64)           256
#  hNormalization)
#
#  re_lu_2 (ReLU)              (None, 88, 64)            0
#
#  max_pooling1d_2 (MaxPooling  (None, 44, 64)           0
#  1D)
#
#  lstm_29 (LSTM)              (None, 44, 512)           1181696
#
#  dropout_28 (Dropout)        (None, 44, 512)           0
#
#  lstm_30 (LSTM)              (None, 44, 256)           787456
#
#  dropout_29 (Dropout)        (None, 44, 256)           0
#
#  lstm_31 (LSTM)              (None, 44, 128)           197120
#
#  dropout_30 (Dropout)        (None, 44, 128)           0
#
#  lstm_32 (LSTM)              (None, 64)                49408
#
#  dropout_31 (Dropout)        (None, 64)                0
#
#  dense_20 (Dense)            (None, 64)                4160
#
#  dense_21 (Dense)            (None, 32)                2080
#
#  dense_22 (Dense)            (None, 3)                 99
#
# =================================================================
# Total params: 2,246,531
# Trainable params: 2,246,403
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# # 8. Make Predictions

# %%
predict_res = model.predict(X_test)
# Out:
# 7/7 [==============================] - 2s 4ms/step

# %% [markdown]
# # 9. Save Weights

# %%
#단일 file/folder 에 모델의 아키텍처, 가중치 및 훈련 구성을 저장
# pose + hands : model_44_258.h5
# hands : model_44_126.h5
# pose 일부 + hands + face 일부 : model_44.220.h5
# pose + hands + face 일부 : model_44_312.h5
model.save('model_44_258(3).h5')

# %%
model.load_weights('model_44_258.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# 14/14 [==============================] - 2s 9ms/step

# %%
#y_test의 값들이 가리키는 label들을 하나의 리스트로 변환
#ex. [[0, 0, 1], [0, 1, 0]] -> [2, 1]
ytrue = np.argmax(y_test, axis=1).tolist()
#yhat의 값들이 가리키는 label들을 하나의 리스트로 변환
#ex. [[0.1, 0.2, 0.7], [0.1, 0.8, 0.1]] -> [2, 1]
yhat = np.argmax(yhat, axis=1).tolist()

# %%
#returns a confusion matrix sorted by the label order
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[427,   0],
#         [  0,  13]],
#
#        [[433,   0],
#         [  0,   7]],
#
#        [[430,   0],
#         [  0,  10]],
#
#        [[429,   0],
#         [  1,  10]],
#
#        [[431,   0],
#         [  0,   9]],
#
#        [[431,   0],
#         [  0,   9]],
#
#        [[428,   1],
#         [  0,  11]],
#
#        [[431,   0],
#         [  0,   9]],
#
#        [[426,   0],
#         [  0,  14]],
#
#        [[430,   0],
#         [  1,   9]],
#
#        [[427,   0],
#         [  0,  13]],
#
#        [[432,   0],
#         [  0,   8]],
#
#        [[429,   0],
#         [  0,  11]],
#
#        [[431,   0],
#         [  0,   9]],
#
#        [[432,   0],
#         [  0,   8]],
#
#        [[432,   0],
#         [  0,   8]],
#
#        [[432,   0],
#         [  0,   8]],
#
#        [[428,   0],
#         [  0,  12]],
#
#        [[431,   0],
#         [  0,   9]],
#
#        [[429,   0],
#         [  0,  11]],
#
#        [[431,   0],
#         [  0,   9]],
#
#        [[425,   0],
#         [  6,   9]],
#
#        [[429,   0],
#         [  1,  10]],
#
#        [[427,   0],
#         [  0,  13]],
#
#        [[432,   0],
#         [  0,   8]],
#
#        [[431,   0],
#         [  0,   9]],
#
#        [[431,   0],
#         [  0,   9]],
#
#        [[428,   0],
#         [  0,  12]],
#
#        [[435,   0],
#         [  0,   5]],
#
#        [[426,   1],
#         [  0,  13]],
#
#        [[421,   0],
#         [  0,  19]],
#
#        [[428,   0],
#         [  0,  12]],
#
#        [[430,   0],
#         [  0,  10]],
#
#        [[431,   0],
#         [  0,   9]],
#
#        [[431,   0],
#         [  4,   5]],
#
#        [[428,   1],
#         [  0,  11]],
#
#        [[426,   8],
#         [  0,   6]],
#
#        [[433,   0],
#         [  6,   1]],
#
#        [[432,   0],
#         [  0,   8]],
#
#        [[430,   0],
#         [  9,   1]],
#
#        [[416,  12],
#         [  7,   5]],
#
#        [[419,  14],
#         [  0,   7]],
#
#        [[432,   3],
#         [  3,   2]],
#
#        [[429,   0],
#         [  2,   9]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.9090909090909091

# %% [markdown]
# # 11-1. Test using video

# %%
#한글 텍스트 출력
from PIL import ImageFont, ImageDraw, Image

def putKoreanText(src, text, pos, font_size, font_color):
    img_pil = Image.fromarray(src)
    draw = ImageDraw.Draw(img_pil)
    font = ImageFont.truetype('C:/Users/User/ActionDetectionforSignLanguage/fonts/gulim.ttc', font_size)
    draw.text(pos, text, font=font, fill= font_color)
    return np.array(img_pil)

# %%
# prediction using video
def video_prediction(video):
    
    # 1. detection variables
    sequence = [] #collect 60 frames to make a sequence(=video)
    sentence = [] #concatenate history of predictions together
    threshold = 0.995

    cap = cv2.VideoCapture(video)
    
    #clear subtitles when {clear_cycle} frames passed without new subtitle added
    frames_without_new_subtitle = 0
    clear_cycle = 300
    
    word = ''
    cnt = 0
    
    # Set mediapipe model 
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        while cap.isOpened():
            # Read video
            ret, frame = cap.read()
            if ret == False:
                break
                
            # Make detections
            image, results = mediapipe_detection(frame, holistic)
            print(results)
            # Draw landmarks
            draw_styled_landmarks(image, results)

            # 2. Prediction logic
            keypoints = extract_keypoints(results)
            sequence.append(keypoints)
            sequence = sequence[-60:] #generate sequence with last 30 frames
            
            #frames_without_new_subtitle += 1

            if len(sequence) == 60:
                #sequence.shape = (60, 1662)
                #the input shape model expects = (number of sequences, 60, 1662)
                res = model.predict(np.expand_dims(sequence, axis=0))[0]
                print(actions[np.argmax(res)])
                
                if word == actions[np.argmax(res)]:
                    cnt = cnt + 1
                else :
                    word = actions[np.argmax(res)]
                    cnt = 0
                    

                #3. Rendering logic
                #ex. res = [0.1, 0.2, 0.7]
                #np.argmax(res) = 2, res[np.argmax(res)] = 0.7
                if res[np.argmax(res)] > threshold and cnt >= 30: 
                    #new subtitle added
                    #frames_without_new_subtitle = 0

                    cur_action_korean = actions[np.argmax(res)]

                    if len(sentence) > 0: 
                        #sentence에 저장된 prediction이 있는 경우 
                        #새로운 prediction인 경우에만 sentence에 추가
                        if cur_action_korean != sentence[-1]:
                            sentence.append(cur_action_korean)
                    else: 
                        #sentence에 저장된 prediction 없는 경우 바로 sentence에 추가
                        sentence.append(cur_action_korean)

                #sentence가 너무 길어지지 않도록 마지막 5개의 prediction만 유지
                if len(sentence) > 5: 
                    sentence = sentence[-5:]
                
                #Clear subtitles if needed
#                if frames_without_new_subtitle >= clear_cycle:
#                    sentence.clear()
                
                #Render subtitles
                cv2.rectangle(image, (0,0), (640, 40), (0, 0, 0), -1) 
#                if target == 'ko':
#                    #putKoreanText(src, text, pos, font_size, font_color
#                    image = putKoreanText(image, ' '.join(sentence), (3,10), 20, (255, 255, 255))
#                else:
#                    cv2.putText(image, ' '.join(sentence), (3,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
                image = putKoreanText(image, ' '.join(sentence), (3,10),(20),(255,255,255))
                # Show to screen
                cv2.imshow('Video Prediction', image)

            # Break gracefully
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
                
    cap.release()
    cv2.destroyAllWindows()

# %%
# prediction using video
def custom_video_prediction(video):
    
    # 1. detection variables
    sequence = [] #collect 60 frames to make a sequence(=video)
    sentence = [] #concatenate history of predictions together
    threshold = 0.995

    cap = cv2.VideoCapture(video)
    
    #clear subtitles when {clear_cycle} frames passed without new subtitle added
    frames_without_new_subtitle = 0
    clear_cycle = 300
    
    word = ''
    cnt = 0
    frame_num = 0
    
    # Set mediapipe model 
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        while cap.isOpened():
            # Read video
            ret, frame = cap.read()
            if ret == False:
                break
                
            frame_num = frame_num+1
            
            if frame_num%2 == 0:
                continue

            
            # Make detections
            image, results = mediapipe_detection(frame, holistic)
            print(results)
            # Draw landmarks
            draw_styled_landmarks(image, results)
            #draw_custom_pose_landmarks(image, results)
            #draw_custom_hand_landmarks(image, results)
            #draw_custom_face_landmarks(image, results)

            # 2. Prediction logic
            keypoints = extract_keypoints_258(results)
            sequence.append(keypoints)
            sequence = sequence[-30:] #generate sequence with last 30 frames
            
            #frames_without_new_subtitle += 1

            if len(sequence) == 30:
                #sequence.shape = (60, 1662)
                #the input shape model expects = (number of sequences, 60, 1662)
                res = model.predict(np.expand_dims(sequence, axis=0))[0]
                print(actions[np.argmax(res)])
                
                if word == actions[np.argmax(res)]:
                    cnt = cnt + 1
                else :
                    word = actions[np.argmax(res)]
                    cnt = 1
                    

                #3. Rendering logic
                #ex. res = [0.1, 0.2, 0.7]
                #np.argmax(res) = 2, res[np.argmax(res)] = 0.7
                if res[np.argmax(res)] > threshold and cnt >= 10: 
                    #new subtitle added
                    #frames_without_new_subtitle = 0

                    cur_action_korean = actions[np.argmax(res)]

                    if len(sentence) > 0: 
                        #sentence에 저장된 prediction이 있는 경우 
                        #새로운 prediction인 경우에만 sentence에 추가
                        if cur_action_korean != sentence[-1]:
                            sentence.append(cur_action_korean)
                    else: 
                        #sentence에 저장된 prediction 없는 경우 바로 sentence에 추가
                        sentence.append(cur_action_korean)

                #sentence가 너무 길어지지 않도록 마지막 5개의 prediction만 유지
                if len(sentence) > 5: 
                    sentence = sentence[-5:]
                
                #Clear subtitles if needed
#                if frames_without_new_subtitle >= clear_cycle:
#                    sentence.clear()
                
                #Render subtitles
                cv2.rectangle(image, (0,0), (640, 40), (0, 0, 0), -1) 
#                if target == 'ko':
#                    #putKoreanText(src, text, pos, font_size, font_color
#                    image = putKoreanText(image, ' '.join(sentence), (3,10), 20, (255, 255, 255))
#                else:
#                    cv2.putText(image, ' '.join(sentence), (3,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
                image = putKoreanText(image, ' '.join(sentence), (3,10),(20),(255,255,255))
                # Show to screen
                cv2.imshow('Video Prediction', image)

            # Break gracefully
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
                
    cap.release()
    cv2.destroyAllWindows()

# %%
curDir = "C:/Users/wjdgu/JupyterMain/ActionDetectionforSignLanguage/videos/손"
for file in os.listdir(curDir):
    if(file.endswith(".mp4")):
        path = os.path.join(curDir, file)
        custom_video_prediction(path)
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# 팔
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 17ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# 팔
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 16ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 13ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 15ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 14ms/step
# 손
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[112], line 5
#       3 if(file.endswith(".mp4")):
#       4     path = os.path.join(curDir, file)
# ----> 5     custom_video_prediction(path)
#
# Cell In[110], line 34, in custom_video_prediction(video)
#      30     continue
#      33 # Make detections
# ---> 34 image, results = mediapipe_detection(frame, holistic)
#      35 print(results)
#      36 # Draw landmarks
#
# Cell In[3], line 6, in mediapipe_detection(image, model)
#       4 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR -> RGB
#       5 image.flags.writeable = False                  # Image is no longer writeable
# ----> 6 results = model.process(image)                 # Make prediction
#       7 image.flags.writeable = True                   # Image is now writeable
#       8 image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB -> BGR
#
# File ~\anaconda3\lib\site-packages\mediapipe\python\solutions\holistic.py:160, in Holistic.process(self, image)
#     136 def process(self, image: np.ndarray) -> NamedTuple:
#     137   """Processes an RGB image and returns the pose landmarks, left and right hand landmarks, and face landmarks on the most prominent person detected.
#     138
#     139   Args:
#    (...)
#     157          "enable_segmentation" is set to true.
#     158   """
# --> 160   results = super().process(input_data={'image': image})
#     161   if results.pose_landmarks:  # pytype: disable=attribute-error
#     162     for landmark in results.pose_landmarks.landmark:  # pytype: disable=attribute-error
#
# File ~\anaconda3\lib\site-packages\mediapipe\python\solution_base.py:365, in SolutionBase.process(self, input_data)
#     359   else:
#     360     self._graph.add_packet_to_input_stream(
#     361         stream=stream_name,
#     362         packet=self._make_packet(input_stream_type,
#     363                                  data).at(self._simulated_timestamp))
# --> 365 self._graph.wait_until_idle()
#     366 # Create a NamedTuple object where the field names are mapping to the graph
#     367 # output stream names.
#     368 solution_outputs = collections.namedtuple(
#     369     'SolutionOutputs', self._output_stream_type_info.keys())
#
# KeyboardInterrupt:

# %% [markdown]
# # 11-2. Test in Real Time

# %%
#한글 텍스트 출력
from PIL import ImageFont, ImageDraw, Image

def putKoreanText(src, text, pos, font_size, font_color):
    img_pil = Image.fromarray(src)
    draw = ImageDraw.Draw(img_pil)
    font = ImageFont.truetype('C:/Users/User/ActionDetectionforSignLanguage/fonts/gulim.ttc', font_size)
    draw.text(pos, text, font=font, fill= font_color)
    return np.array(img_pil)

# %%
# 1. detection variables
sequence = [] #collect 60 frames to make a sequence(=video)
sentence = [] #concatenate history of predictions together
threshold = 0.995

word = ''
cnt = 0

cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()
        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:] #generate sequence with last 30 frames
        
        if len(sequence) == 30:
            #sequence.shape = (60, 1662)
            #the input shape model expects = (number of sequences, 60, 1662)
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])

            if word == actions[np.argmax(res)]:
                cnt = cnt + 1
            else :
                word = actions[np.argmax(res)]
                cnt = 1


            #3. Rendering logic
            #ex. res = [0.1, 0.2, 0.7]
            #np.argmax(res) = 2, res[np.argmax(res)] = 0.7
            if res[np.argmax(res)] > threshold and cnt >= 10: 
                #new subtitle added
                #frames_without_new_subtitle = 0

                cur_action_korean = actions[np.argmax(res)]

                if len(sentence) > 0: 
                    #sentence에 저장된 prediction이 있는 경우 
                    #새로운 prediction인 경우에만 sentence에 추가
                    if cur_action_korean != sentence[-1]:
                        sentence.append(cur_action_korean)
                else: 
                    #sentence에 저장된 prediction 없는 경우 바로 sentence에 추가
                    sentence.append(cur_action_korean)

            #sentence가 너무 길어지지 않도록 마지막 5개의 prediction만 유지
            if len(sentence) > 5: 
                sentence = sentence[-5:]

            #Clear subtitles if needed
#                if frames_without_new_subtitle >= clear_cycle:
#                    sentence.clear()

            #Render subtitles
            cv2.rectangle(image, (0,0), (640, 40), (0, 0, 0), -1) 
#                if target == 'ko':
#                    #putKoreanText(src, text, pos, font_size, font_color
#                    image = putKoreanText(image, ' '.join(sentence), (3,10), 20, (255, 255, 255))
#                else:
#                    cv2.putText(image, ' '.join(sentence), (3,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
            image = putKoreanText(image, ' '.join(sentence), (3,10),(20),(255,255,255))
            # Show to screen
            cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
            
    cap.release()
    cv2.destroyAllWindows()
